# %%
pip install scikit-learn

from sklearn.tree import DecisionTreeClassifier
import numpy as np

# Training data (ratings)
X = np.array([[1], [2], [3], [4], [5]])

# Labels (AI learns these meanings)
y = [
    "Very Poor 😡",
    "Poor 😕",
    "Average 🙂",
    "Good 😊",
    "Excellent 🤩"
]

# Create AI model
model = DecisionTreeClassifier()

# Train the model
model.fit(X, y)

# User input
rating = int(input("Enter rating (1 to 5): "))

# Predict review
review = model.predict([[rating]])

print("AI Generated Review:", review[0])
