# %%
s = "hello"
print(len(s))   # 5
# Out:
# 5

# %%
s.upper()
# Out:
# 'HELLO'

# %%
demo="krish patel"

# %%
demo.title()
# Out:
# 'Krish Patel'

# %%
print("   hello   ".strip())   # "hello"
# Out:
# hello

# %%
demo.replace("Patel","H Paetl")
# Out:
# 'krish patel'

# %%
demo.replace("patel","H")
# Out:
# 'krish H'

# %%
print("a b c".split())  
# ['a', 'b', 'c']
# Out:
# ['a', 'b', 'c']

# %%
name="Krish "
name1=" Patel"

# %%
name.join(name1)
# Out:
# ' Krish PKrish aKrish tKrish eKrish l'
