# %%
l = ["Krish","H","Patel"]

# %%
for i in l:#Use Pass Keyword 
    pass
    
print("Krish")
# Out:
# Krish

# %%
lt = ["apple", "banana", "graps"]

for item in lt:
    if item == "banana":
        continue
    print(item)
# Out:
# apple
# graps
