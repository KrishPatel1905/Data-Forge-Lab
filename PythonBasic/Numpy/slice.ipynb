# %%
import numpy as np

# %%
arr = np.array([10,20,30,40,50,60])
print(arr)
# Out:
# [10 20 30 40 50 60]

# %%
b =arr[3:7]
b    # so here b is not sub part of arr it is itself original array means that if 
     # we will chnage inside b that means that we will be directly effect on original array that as below given code
# Out:
# array([40, 50, 60])

# %%
b[0] = 4

# %%
print(arr)
# Out:
# [10 20 30  4 50 60]

# %%
arr[arr>30] # boolean masking
# Out:
# array([50, 60])

# %%
print(arr.dtype)
# Out:
# int64

# %%
arr.astype("float64")
# Out:
# array([10., 20., 30.,  4., 50., 60.])

# %%
arr.nbytes
# Out:
# 48
