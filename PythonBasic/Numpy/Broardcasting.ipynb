# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
result=  arr ** 2  #Vectorized Operation using Batch Concept (SIMD)
print(result)
# Out:
# [ 1  4  9 16 25]

# %%
result + 10
# Out:
# array([11, 14, 19, 26, 35])

# %%
arr1 = np.array([[10,20,30],[40,50,60]])
arr2 = np.array([5,5,5])

result = arr1+arr2
print(result)
# Out:
# [[15 25 35]
#  [45 55 65]]

# %%
np.mean(arr)
# Out:
# np.float64(3.0)

# %%
np.std(arr)
# Out:
# np.float64(1.4142135623730951)

# %%
np.max(arr)
# Out:
# np.int64(5)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
np.prod(arr)
# Out:
# np.int64(120)

# %%
np.median(arr)
# Out:
# np.float64(3.0)

# %%
np.percentile(arr, 60)  # For the 50th percentile (median)
# Out:
# np.float64(3.4)

# %%
np.log(arr)
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436, 1.60943791])

# %%
np.exp(arr)
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692,  54.59815003,
#        148.4131591 ])
