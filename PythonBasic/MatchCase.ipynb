# %%
code =2002

# %%
match(code):
    case 200 :
        print("Ok All Done ")
    case 400:
         print("Server Error ")
    case 404:
          print("Server Not Found ")
    case _:
        print("Somthing Went Wrong ")
# Out:
# Somthing Went Wrong
