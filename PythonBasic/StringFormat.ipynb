# %%
name ="Xyz"
age="50"

# %%
print("he name is {} and he age is {}".format(name,age))
#But This is old style to format string
# Out:
# he name is Xyz and he age is 50

# %%
#Update Version is fsting method which is py 3.6 onwards 
print (f"he name is :{name} and he age is :{age}")
# Out:
# he name is :Xyz and he age is :50

# %%
#alignment of word

# %%
print(f"{'Python ':<10}") #left align
print(f"{'Python ':>10}") #Right align
print(f"{'Python ':^10}") #Center align
# Out:
# Python
#    Python
#  Python
