# %%
l = [10,20,30,40,50]

# %%
print(l)
# Out:
# [10, 20, 30, 40, 50]

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l[3]
# Out:
# 40

# %%
l[3] = 50

# %%
l
# Out:
# [10, 20, 30, 50, 50]

# %%
l1=[19,5]

# %%
l.append(l1)

# %%
l
# Out:
# [10, 20, 30, 50, 50, [19, 5]]

# %%
l.insert(3,40)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 50, [19, 5]]

# %%
number = l.pop(4)

# %%
number
# Out:
# 50

# %%
l
# Out:
# [10, 20, 30, 40, 50, [19, 5]]

# %%
l.index([19,5])
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 50, [19, 5]]

# %%
l.pop(5)
# Out:
# [19, 5]

# %%
l.sort()
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 l.sort()
#       2 l
#
# NameError: name 'l' is not defined

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined
