# %%
l= [15,10,5,25,20]

# %%
sorted(l) # sorted method create a new list
# Out:
# [5, 10, 15, 20, 25]

# %%
l
# Out:
# [15, 10, 5, 25, 20]

# %%
l.sort() # sort function change(sort) main list

# %%
l
# Out:
# [5, 10, 15, 20, 25]

# %%
10 in l
# Out:
# True

# %%
if 10 in l:
    print("Yes")
# Out:
# Yes
