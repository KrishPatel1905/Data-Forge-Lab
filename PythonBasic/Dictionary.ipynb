# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s=set()
type(s)
# Out:
# set

# %%
#Dictionary with key and value 
student = {
       "name" : "Krish",
        "age" : 25,
         "Id" : 101
        
}
student1 ={
    "name" : "Heet",
    "age" : 27,
    "Id" : 102
}

# %%
student["name"]
student["age"]
student["Id"]
# Out:
# 101

# %%
#studen["name1"] --> it give me error bcz name1 which is key 
#does not exit student dictionary for that we have solution 
#about get method in dic

student.get("name")

#if i am writing like this name1 so it dont show me error 
r = student.get("name1")

print(r)
# Out:
# None

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'Id'])

# %%
student.values()
# Out:
# dict_values(['Krish', 25, 101])

# %%
student
# Out:
# {'name': 'Krish', 'age': 25, 'Id': 101}

# %%
student.items()
# Out:
# dict_items([('name', 'Krish'), ('age', 25), ('Id', 101)])

# %%
student.update(student1)

# %%
student
# Out:
# {'name': 'Heet', 'age': 27, 'Id': 102}

# %%
student1
# Out:
# {'name': 'Heet', 'age': 27, 'Id': 102}

# %%
student.update({"name": "Krish"})

# %%
student.update({"age": 25})

# %%
student
# Out:
# {'name': 'Krish', 'age': 25, 'Id': 102}

# %%
	student.setdefault("city", "Unknown")
# Out:
# 'Unknown'

# %%
student
# Out:
# {'name': 'Krish', 'age': 25, 'Id': 102, 'city': 'Unknown'}

# %%
student.setdefault("age" , 20)
# Out:
# 25

# %%
student
# Out:
# {'name': 'Krish', 'age': 25, 'Id': 102, 'city': 'Unknown'}

# %%
student2 = student.copy()

# %%
student2
# Out:
# {'name': 'Krish', 'age': 25, 'Id': 102, 'city': 'Unknown'}
