# %%
f = open("try.txt","w")

string = ''' Hello My name is krish
             And this is try.txt file 
             and also i am learing python      
                   '''
f.write(string)
f.close()
