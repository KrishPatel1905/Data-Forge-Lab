# %%
empty = set()

# %%
type(empty)
# Out:
# set

# %%
number ={1,2,3,2,1,4,5}
number
# Out:
# {1, 2, 3, 4, 5}

# %%
#CONVERT LIST INTO SET FOR FIND UNIQUE ELEMENT
l= [10,20,30,20,40,30]
unique_number = set([10,20,30,20,40,30])
unique_number
# Out:
# {10, 20, 30, 40}

# %%
number.discard(1)

# %%
number
# Out:
# {2, 3, 4, 5}

# %%
number.pop()
# Out:
# 2

# %%
number
# Out:
# {3, 4, 5}
