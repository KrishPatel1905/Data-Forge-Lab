# %%
f = open("demo.txt","r")

# %%
f.read()
# Out:
# 'Hi My Name Is Krish'

# %%
f.close()

# %%
f = open("demo1.txt","w")

# %%
f.write("And i am study in charusat")
# Out:
# 26

# %%
f.close()

# %%
f = open("demo.txt","r")

# %%
f.read()
# Out:
# 'And i am study in charusat'

# %%
import os

if os.path.exists("example.txt"):
    print("File exists!")
else:
    print("File not found!")
# Out:
# File not found!

# %%
import os

if os.path.exists("demo.txt"):
    print("File exists!")
else:
    print("File not found!")
# Out:
# File exists!

# %%
if os.path.exists("example.txt"):
    os.remove("example.txt")
else:
    print("File Does Not Exit ")
