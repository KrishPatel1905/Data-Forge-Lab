# %%
data = {"name " : "Krish", "age": 20,"city" : "Unjha"}

# %%
js = json.dumps(data)

# %%
js
# Out:
# '{"name ": "Krish", "age": 20, "city": "Unjha"}'

# %%
type(js)
# Out:
# str

# %%
data1 = '{"name " : "Heet", "age": 22,"city" : "Anand"}'

# %%
js1 = json.loads(data1)

# %%
js1
# Out:
# {'name ': 'Heet', 'age': 22, 'city': 'Anand'}
