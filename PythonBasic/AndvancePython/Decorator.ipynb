# %%
# Decorator is nothing but its take funcation as argument

def A(fun):
    def B():
        print("My Name is B..")
        fun()
        print("Hello My name is nothing ...")
    return B
@A  # we call by explicatiy like A function take by you as argument ...
def Demo():
    print("My name is Demo ....")

Demo()
# Method 1 using stoting function into f
# f = A(Demo)
# print(f())
# Out:
# My Name is B..
# My name is Demo ....
# Hello My name is nothing ...
