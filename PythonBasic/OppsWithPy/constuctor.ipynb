# %%
class Emp:
    def __init__(self,name,salary,exp):
        self.name= name
        self.salary = salary
        self.exp = exp
e = Emp("Krish","1 cr ","5 yr") 
print(e.name,e.salary,e.exp,sep="\n")
# Out:
# Krish
# 1 cr
# 5 yr
