# %%
a = 3

# %%
if(a>100):
        print("a is lesser than 10")
elif(a>40):
    print("a is lesser than 40")
elif(a>30):
    print("a is lesser than 30")
else:
    print("And All Set ....")
# Out:
# And All Set ....

# %%
# User define function

# %%
def avg(a,b):
      print((a+b)//2)

# %%
  avg(20,10)
# Out:
# 15
