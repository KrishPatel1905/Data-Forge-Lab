# %%
a=input("Enter the value of a :")#By default take value as string
# Out:
# Enter the value of a : 10

# %%
b=input("Enter the value of b:")
# Out:
# Enter the value of b: 5

# %%
a+b
# Out:
# '105'

# %%
int(a)/int(b) #By dafault give ans as float
# Out:
# 2.0

# %%
int(a)//int(b) #// --> Must Give Ans as Int
# Out:
# 2

# %%
int(a)*int(b)
# Out:
# 50

# %%
int(a)**int(b)# ** ---> Exponationtal From
# Out:
# 100000
