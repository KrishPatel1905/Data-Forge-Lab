# %%
#Variable

# %%
a=5

# %%
b=4

# %%
a+b
# Out:
# 9

# %%
print(a+b)
# Out:
# 9

# %%
name ="Krish "

# %%
name1="Patel"

# %%
print(name+name1)
# Out:
# Krish Patel

# %%
#type variabole

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(name)) ;print(type(name1))
# Out:
# <class 'str'>
# <class 'str'>

# %%
#type conversion

# %%
x= "500"

# %%
y="100"

# %%
x+y
# Out:
# '500100'

# %%
int(x)+ int(y)
# Out:
# 600
