# %%
# !pip install pandas

# %%
import pandas as pd
s1=pd.Series([98,95,90,85,92])

# %%
s1
# Out:
# 0    98
# 1    95
# 2    90
# 3    85
# 4    92
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2= pd.Series([98,95,90,85,92],index=["DS","DAA","SE","DBMS","COA"])

# %%
s2
# Out:
# DS      98
# DAA     95
# SE      90
# DBMS    85
# COA     92
# dtype: int64

# %%
s2["DS"]
# Out:
# np.int64(98)

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
pd.DataFrame(s2)
# Out:
#        0
# DS    98
# DAA   95
# SE    90
# DBMS  85
# COA   92

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
