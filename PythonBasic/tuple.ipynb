# %%
t=()#tupple method

# %%
t
# Out:
# ()

# %%
t=(10,20,30,40,50)
t
# Out:
# (10, 20, 30, 40, 50)

# %%
len(t)
# Out:
# 5

# %%
type(t)
# Out:
# tuple

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
#pakking and Unpakking

# %%
man =("Krish",18,"Data Scientiest")

name,age,profession=man

# %%
name
# Out:
# 'Krish'

# %%
age
# Out:
# 18

# %%
profession
# Out:
# 'Data Scientiest'
